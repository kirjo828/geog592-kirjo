# %%
import pandas as pd

# Read the CSV into a DataFrame

filename = "data/ElectricCar_clean.csv"

df = pd.read_csv(filename)

# Explore the Data

df.head()

df.shape

df.columns

df.dtypes

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7358 entries, 0 to 7357
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model             7358 non-null   str
#  1   VIN (1-10)        7358 non-null   str
#  2   County            7358 non-null   str
#  3   City              7358 non-null   str
#  4   2020 GEOID        7358 non-null   int64
#  5   State             7358 non-null   str
#  6   Vehicle Location  7358 non-null   str
# dtypes: int64(1), str(6)
# memory usage: 402.5 KB

# %%
# Make a Mask

mask = df["County"] == "King"

mask.head()

df2 = df[mask]

df2
# Out:
#         Model  VIN (1-10) County       City   2020 GEOID State  \
# 3        KONA  KM8K33AG7L   King    Seattle  53033003400    WA
# 14       NIRO  KNDCE3LG9K   King    Seattle  53033006000    WA
# 17    MODEL X  5YJXCBE29G   King  Sammamish  53033032317    WA
# 22     E-TRON  WA1VABGE1K   King       Kent  53033031704    WA
# 26    MODEL Y  5YJYGDEF5L   King     Renton  53033029308    WA
# ...       ...         ...    ...        ...          ...   ...
# 7352      EV6  KNDC3DLC8P   King    Seattle  53033000300    WA
# 7354   TAYCAN  WP0AA2Y14R   King   Kirkland  53033022501    WA
# 7355  MODEL S  5YJSA1CN5D   King    Seattle  53033008402    WA
# 7356       I3  WBY1Z4C54F   King       Kent  53033029403    WA
# 7357     LEAF  1N4AZ0CP3G   King   Bellevue  53033024901    WA
#
#                  Vehicle Location
# 3     POINT (-122.38591 47.67597)
# 14    POINT (-122.36381 47.63046)
# 17    POINT (-122.02054 47.60326)
# 22    POINT (-122.10798 47.37124)
# ...
